# %%
import tabula 
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import numpy as np
import csv

pd.set_option("display.max_rows", 150)
pd.set_option("display.max_columns", 150)
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
from io import StringIO
# pip install pdfminer.six
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

def convert_pdf_to_string(file_path):
    output_string = StringIO()
    with open(file_path, 'rb') as in_file:
        parser = PDFParser(in_file)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()
        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)
    return(output_string.getvalue())

# %%
pdf_str = convert_pdf_to_string("raw-from-source/2018generalofficialresults.pdf")

# %%
pdf_pages = pdf_str.split("\n\n\x0c")

# remove blank pages 
pdf_pages = [p for p in pdf_pages if len(p) >= 30]

print(len(pdf_pages))
# Out:
# 211

# %%
positions = set(["Senator", "Governor", "Treasurer", "Secretary", "General", "Auditor", "Congress"])
positions = set([p.upper() for p in positions])

county_page_idxs = []
for idx, page in enumerate(pdf_pages):
    if "County" in page and len(positions.difference(set(page.split()))) < len(positions):
        county_page_idxs.append(idx)


idx2county = {}
for idx in county_page_idxs:
    page = pdf_pages[idx]
    county = page[:page.index("County")].split()[-1]
    idx2county[idx] = county
    
county2idx_list = [(val, key) for key, val in idx2county.items()]
county2idx_list.append(("End File", 212))
print(county2idx_list)
# Out:
# [('Addison', 4), ('Bennington', 8), ('Caledonia', 10), ('Chittenden', 12), ('Essex', 14), ('Franklin', 16), ('Isle', 18), ('Lamoille', 20), ('Orange', 22), ('Orleans', 24), ('Rutland', 28), ('Washington', 32), ('Windham', 36), ('Windsor', 40), ('Addison', 45), ('Bennington', 47), ('Caledonia', 48), ('Chittenden', 49), ('Essex', 50), ('Franklin', 51), ('Isle', 52), ('Lamoille', 53), ('Orange', 54), ('Orleans', 55), ('Rutland', 57), ('Washington', 59), ('Windham', 61), ('Windsor', 63), ('Addison', 66), ('Bennington', 70), ('Caledonia', 72), ('Chittenden', 74), ('Essex', 76), ('Franklin', 78), ('Isle', 80), ('Lamoille', 82), ('Orange', 84), ('Orleans', 86), ('Rutland', 90), ('Washington', 94), ('Windham', 98), ('Windsor', 102), ('Addison', 107), ('Bennington', 109), ('Caledonia', 110), ('Chittenden', 111), ('Essex', 112), ('Franklin', 113), ('Isle', 114), ('Lamoille', 115), ('Orange', 116), ('Orleans', 117), ('Rutland', 119), ('Washington', 121), ('Windham', 123), ('Windsor', 125), ('Addison', 128), ('Bennington', 130), ('Caledonia', 131), ('Chittenden', 132), ('Essex', 133), ('Franklin', 134), ('Isle', 135), ('Lamoille', 136), ('Orange', 137), ('Orleans', 138), ('Rutland', 140), ('Washington', 142), ('Windham', 144), ('Windsor', 146), ('Addison', 149), ('Bennington', 151), ('Caledonia', 152), ('Chittenden', 153), ('Essex', 154), ('Franklin', 155), ('Isle', 156), ('Lamoille', 157), ('Orange', 158), ('Orleans', 159), ('Rutland', 161), ('Washington', 163), ('Windham', 165), ('Windsor', 167), ('Addison', 170), ('Bennington', 172), ('Caledonia', 173), ('Chittenden', 174), ('Essex', 175), ('Franklin', 176), ('Isle', 177), ('Lamoille', 178), ('Orange', 179), ('Orleans', 180), ('Rutland', 182), ('Washington', 184), ('Windham', 186), ('Windsor', 188), ('Addison', 191), ('Bennington', 193), ('Caledonia', 194), ('Chittenden', 195), ('Essex', 196), ('Franklin', 197), ('Isle', 198), ('Lamoille', 199), ('Orange', 200), ('Orleans', 201), ('Rutland', 203), ('Washington', 205), ('Windham', 207), ('Windsor', 209), ('End File', 212)]

# %%
file = "raw-from-source/2018generalofficialresults.pdf"
tables = tabula.read_pdf(file, pages = "all", multiple_tables = True)

# %%
print(len(tables))
# Out:
# 211

# %%
tables[10]
# Out:
#           Unnamed: 0  Bernie Sanders Brad J. Peacock  Bruce Busa  \
# 0             BARNET   479    58.92%     11    1.35%  2    0.25%
# 1              BURKE   431    60.88%      5    0.71%  0    0.00%
# 2           DANVILLE   652    56.35%      8    0.69%  4    0.35%
# 3             GROTON   203    49.15%      3    0.73%  0    0.00%
# 4           HARDWICK   727    62.56%     11    0.95%  5    0.43%
# 5              KIRBY   139    56.28%      3    1.21%  0    0.00%
# 6             LYNDON   876    51.20%     16    0.94%  7    0.41%
# 7             NEWARK   141    54.86%      5    1.95%  0    0.00%
# 8            PEACHAM   289    66.74%      4    0.92%  0    0.00%
# 9            RYEGATE   249    56.85%      1    0.23%  1    0.23%
# 10  SAINT\rJOHNSBURY  1483    59.51%     22    0.88%  9    0.36%
# 11         SHEFFIELD   139    55.38%      3    1.20%  1    0.40%
# 12          STANNARD    75    81.52%      0    0.00%  0    0.00%
# 13            SUTTON   181    51.57%      5    1.42%  1    0.28%
# 14            WALDEN   265    58.89%      3    0.67%  3    0.67%
# 15         WATERFORD   286    47.91%      5    0.84%  1    0.17%
# 16          WHEELOCK   188    56.46%      2    0.60%  0    0.00%
# 17      County Total           6,803             107          34
#
#    Edward S. Gilber Folasade Adeluo Jon Svitavsky Lawrence Zupan    Reid Kane  \
# 0       10    1.23%      5    0.62%    1    0.12%  279    34.32%   3    0.37%
# 1        6    0.85%      7    0.99%    1    0.14%  239    33.76%   3    0.42%
# 2       15    1.30%      6    0.52%    1    0.09%  416    35.96%   5    0.43%
# 3       17    4.12%      0    0.00%    1    0.24%  176    42.62%   2    0.48%
# 4       23    1.98%      1    0.09%    5    0.43%  358    30.81%   7    0.60%
# 5        3    1.21%      3    1.21%    9    3.64%   86    34.82%   0    0.00%
# 6       18    1.05%     12    0.70%    6    0.35%  721    42.14%   6    0.35%
# 7        1    0.39%      2    0.78%    1    0.39%  100    38.91%   2    0.78%
# 8        8    1.85%      2    0.46%    1    0.23%  113    26.10%   2    0.46%
# 9        5    1.14%      7    1.60%    2    0.46%  166    37.90%   1    0.23%
# 10      31    1.24%     10    0.40%    9    0.36%  831    33.35%  16    0.64%
# 11       4    1.59%      0    0.00%    1    0.40%   96    38.25%   1    0.40%
# 12       3    3.26%      0    0.00%    0    0.00%   14    15.22%   0    0.00%
# 13       5    1.42%      0    0.00%    2    0.57%  144    41.03%   2    0.57%
# 14       9    2.00%      0    0.00%    0    0.00%  154    34.22%   3    0.67%
# 15       6    1.01%      5    0.84%    2    0.34%  272    45.56%   0    0.00%
# 16       2    0.60%      0    0.00%    5    1.50%  131    39.34%   0    0.00%
# 17              166              60            47          4,296           53
#
#    Russell Beste
# 0     9    1.11%
# 1     4    0.56%
# 2    10    0.86%
# 3     4    0.97%
# 4     6    0.52%
# 5     0    0.00%
# 6    15    0.88%
# 7     1    0.39%
# 8     1    0.23%
# 9     3    0.68%
# 10   21    0.84%
# 11    2    0.80%
# 12    0    0.00%
# 13    2    0.57%
# 14    1    0.22%
# 15    6    1.01%
# 16    1    0.30%
# 17            86

# %%
county2df = defaultdict(list)
for idx, (county, page_num) in enumerate(county2idx_list[:-1]):
    
    next_county_page_num = county2idx_list[idx + 1][1]
    
    county_len = next_county_page_num - page_num
    
    # there is always a blank page after Windsor
    if county == "Windsor":
        county_len -= 1
    
    # Table small enough to be stored on one page of pdf.
    if county_len == 1:
        df = tables[page_num]

    # Table stored on 2 pages in pdf, 2 different scenarios.
    if county_len == 2:

        df1 = tables[page_num]
        df2 = tables[page_num + 1]
        
        df2 = df2.loc[~df2.index.duplicated()]
        
        # Scenario 1, too many columns to fit on one page, concat horizontally.
        if len(df1) == len(df2):
            df = pd.concat([df1, df2], axis=1)
        # Scenario 2, too many rows to fit on one page, append vertically.
        else:
            df = df1.append(df2)

    # Table has too many rows and cols to fit on one page, only one configuration:
    # page 1 if left-top, page 2 is right-top, page 3 is left-bottom and page 4 
    # is right-bottom of the combined table.
    
    if county_len == 4:

        df1 = tables[page_num]
        
        df2 = tables[page_num + 1]
        if "Unnamed: 0" in df2:
            df2.drop(columns="Unnamed: 0", inplace=True)

        df3 = tables[page_num + 2]
        df4 = tables[page_num + 3]
        
        if "Unnamed: 0" in df4:
            df4.drop(columns="Unnamed: 0", inplace=True)

        first_rows = pd.concat([df1, df2], axis=1)
        second_rows = pd.concat([df3, df4], axis=1)

        df = first_rows.append(second_rows)

    county2df[county].append(df)

# %%
# check that dims are the same between counties
for county, dfs in county2df.items():
    rows = dfs[0].index
    for df in dfs:
        if len(df.index) != len(rows):
            print("wrong length", county, len(df.index), len(rows))
            continue
        
        if (df.index != rows).any():
            print("whoops")

# %%
county2final_df = {key: pd.concat(val, axis=1) for key, val in county2df.items()}

county_columns = county2final_df["Addison"].keys()

# %%
cols = set()
size2county = defaultdict(list)
for key, df in county2final_df.items():
    df_cols = tuple(df.columns.to_list())
    cols.add(df_cols)
    
    size2county[len(df_cols)].append(key)
    
    
# let's see if dfs with same number of columns at least have the same columns
for key, counties in size2county.items():
    print(counties)
    example_cols = tuple(county2final_df[counties[0]].columns.to_list())
    for county in counties:
        compare_cols = tuple(county2final_df[county].columns.to_list())
        if compare_cols != example_cols:
            print(f"Mistake with county: {county}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c8903946fe58> in <module>
#       1 cols = set()
# ----> 2 size2county = defaultdict(list)
#       3 for key, df in county2final_df.items():
#       4     df_cols = tuple(df.columns.to_list())
#       5     cols.add(df_cols)
#
# NameError: name 'defaultdict' is not defined

# %%
rep_counties = ["Addison", "Bennington", "Isle"]
rep_columns = [county2final_df[c].columns.to_list() for c in rep_counties]
orig_columns = rep_columns[0]
for i in [0, 1, 2]:
    rep_columns[i][0] = "NAME"
    
# great! rename the first, remove all unnamed

rep_columns = [[val for val in lst if "Unnamed" not in val] for lst in rep_columns]
    
for a, b, c in zip(*rep_columns):
    print(a, b, c)
# Out:
# NAME NAME NAME
# Bernie Sanders Bernie Sanders Bernie Sanders
# Brad J. Peacock Brad J. Peacock Brad J. Peacock
# Bruce Busa Bruce Busa Bruce Busa
# Edward S. Gilber Edward S. Gilber Edward S. Gilber
# Folasade Adeluo Folasade Adeluo Folasade Adeluo
# Jon Svitavsky Jon Svitavsky Jon Svitavsky
# Lawrence Zupan Lawrence Zupan Lawrence Zupan
# Reid Kane Reid Kane Reid Kane
# Russell Beste Russell Beste Russell Beste
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# Anya Tynio Anya Tynio Anya Tynio
# Cris Ericson Cris Ericson Cris Ericson
# Laura S. Potter Laura S. Potter Laura S. Potter
# Peter Welch Peter Welch Peter Welch
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# Charles Laramie Charles Laramie Charles Laramie
# Christine Hallqu Christine Hallqu Christine Hallqu
# Cris Ericson Cris Ericson Cris Ericson
# Emily "Em" Peyt Emily "Em" Peyt Emily "Em" Peyt
# Phil Scott Phil Scott Phil Scott
# Stephen Marx Stephen Marx Stephen Marx
# Trevor Barlow Trevor Barlow Trevor Barlow
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# David Zuckerma David Zuckerma David Zuckerma
# Don Turner Jr Don Turner Jr Don Turner Jr
# Murray Ngoima Murray Ngoima Murray Ngoima
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# Beth Pearce Beth Pearce Beth Pearce
# Richard Morton Richard Morton Richard Morton
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# H. Brooke Paige H. Brooke Paige H. Brooke Paige
# Jim Condos Jim Condos Jim Condos
# Mary Alice Hebe Mary Alice Hebe Mary Alice Hebe
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# Doug Hoffer Doug Hoffer Doug Hoffer
# Marina Brown Marina Brown Marina Brown
# Richard Kenyon Richard Kenyon Richard Kenyon
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal
# Janssen Willhoit Janssen Willhoit Janssen Willhoit
# Rosemarie Jacko Rosemarie Jacko Rosemarie Jacko
# T.J. Donovan T.J. Donovan T.J. Donovan
# write-in write-in write-in
# overvotes overvotes overvotes
# blank votes blank votes blank votes
# TownTotal TownTotal TownTotal

# %%
vest2can = {l.split(',')[0] : l.split(',')[1].strip() for l in open("raw-from-source/utils/vest2candidate.txt", "r").readlines()}
can2vest = {val : key for key, val in vest2can.items()}

raw2vest = {}
for raw in orig_columns:
    raw = raw.strip()
    for can in can2vest:
        if raw in can:
            vest = can2vest[can]
            raw2vest[raw] = vest
            break

# %%
def assign_raw2vest(name):
    if name in raw2vest:
        return raw2vest[name]
    
    for opt in can2vest:
        if name in opt:
            vest = can2vest[opt]

            raw2vest[name] = vest
            return vest
        
    return name

final_col_names = rep_columns[0]
final_col_names = [assign_raw2vest(val) for val in final_col_names]

# Ericson was an over-achiever and ran for two offices
final_col_names[15] = "G18HALIERI"

for idx, col in enumerate(final_col_names):
    if col == "write-in":
        final_col_names[idx] = final_col_names[idx - 1][:-4] + "OWRI"
        continue
        
    if col == "NAME" or col in vest2can:
        continue
        
    if col == 'Unnamed: 0':
        final_col_names[idx] == "Blank Col"
        continue
        
    final_col_names[idx] = "DROP"

final_col_names = [col for col in final_col_names if col != "DROP"]

# now we just need a way to drop all unnamed from each df, AFTER renaming the first column
final_dfs = []

for key, df in county2final_df.items():
    
    old_cols = df.columns.to_list()
    old_cols[0] = "NAME"
    
    for idx, col in enumerate(old_cols):
        if col == "write-in":
            old_cols[idx] = "write-in" + str(idx)
        if col == "Cris Ericson":
            old_cols[idx] = "Cris Ericson" + str(idx)
    
    df.columns = old_cols
    
    keep_cols = [col for col in old_cols if "Unnamed" not in col \
                 and "blank" not in col and "overvotes" not in col and "TownTotal" not in col]
    
    # cris ericson is doubled 
    
    df = df[keep_cols]
    df.columns = final_col_names
    df["County"] = key
    df["ID"] = key + " " + df["NAME"]
    df.set_index(["ID"], inplace=True)
    
    # remove the percentages from each cell
    cols2reset = [col for col in df.columns if col.startswith("G18")]

    for col in cols2reset:
        df[col] = df[col].astype('str').str.split().str[0]
    
    df.reset_index(inplace=True)
    final_dfs.append(df)

final_dfs[2]
# Out:
# <ipython-input-75-0920a20af8aa>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"] = key
# <ipython-input-75-0920a20af8aa>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ID"] = key + " " + df["NAME"]
# <ipython-input-75-0920a20af8aa>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('str').str.split().str[0]
#                             ID              NAME G18USSISAN G18USSIPEA  \
# 0             Caledonia BARNET            BARNET        479         11
# 1              Caledonia BURKE             BURKE        431          5
# 2           Caledonia DANVILLE          DANVILLE        652          8
# 3             Caledonia GROTON            GROTON        203          3
# 4           Caledonia HARDWICK          HARDWICK        727         11
# 5              Caledonia KIRBY             KIRBY        139          3
# 6             Caledonia LYNDON            LYNDON        876         16
# 7             Caledonia NEWARK            NEWARK        141          5
# 8            Caledonia PEACHAM           PEACHAM        289          4
# 9            Caledonia RYEGATE           RYEGATE        249          1
# 10  Caledonia SAINT\rJOHNSBURY  SAINT\rJOHNSBURY       1483         22
# 11         Caledonia SHEFFIELD         SHEFFIELD        139          3
# 12          Caledonia STANNARD          STANNARD         75          0
# 13            Caledonia SUTTON            SUTTON        181          5
# 14            Caledonia WALDEN            WALDEN        265          3
# 15         Caledonia WATERFORD         WATERFORD        286          5
# 16          Caledonia WHEELOCK          WHEELOCK        188          2
# 17      Caledonia County Total      County Total      6,803        107
#
#    G18USSIBUS G18USSIGIL G18USSIADE G18USSISVI G18USSRZUP G18USSOKAN  \
# 0           2         10          5          1        279          3
# 1           0          6          7          1        239          3
# 2           4         15          6          1        416          5
# 3           0         17          0          1        176          2
# 4           5         23          1          5        358          7
# 5           0          3          3          9         86          0
# 6           7         18         12          6        721          6
# 7           0          1          2          1        100          2
# 8           0          8          2          1        113          2
# 9           1          5          7          2        166          1
# 10          9         31         10          9        831         16
# 11          1          4          0          1         96          1
# 12          0          3          0          0         14          0
# 13          1          5          0          2        144          2
# 14          3          9          0          0        154          3
# 15          1          6          5          2        272          0
# 16          0          2          0          5        131          0
# 17         34        166         60         47      4,296         53
#
#    G18USSIBES G18USSOWRI G18HALRTYN G18HALIERI G18HALOPOT G18HALDWEL  \
# 0           9          0        263         17          5        513
# 1           4          2        243         22          8        421
# 2          10          0        371         36         14        711
# 3           4          0        170         20          9        209
# 4           6          4        343         44         13        742
# 5           0          0         84          4          2        152
# 6          15          0        657         56         27        929
# 7           1          1         97         10          5        139
# 8           1          0         97         13          7        307
# 9           3          0        164          8          2        258
# 10         21          4        795         76         35       1535
# 11          2          0         94          6          4        142
# 12          0          0         14          5          3         70
# 13          2          0        136         11          8        189
# 14          1          1        150         11          9        274
# 15          6          2        251         17          4        305
# 16          1          0        125         15          3        184
# 17         86         14      4,054        371        158      7,080
#
#    G18HALOWRI G18GOVILAR G18GOVDHAL G18GOVIERI G18GOVOPEY G18GOVRSCO  \
# 0           0          6        303          2          6        473
# 1           1          2        238          6          2        429
# 2           0          7        351          4          5        752
# 3           0          5         96          3          5        289
# 4           3         12        415          9          2        680
# 5           0          1         92          0          2        147
# 6           2         10        439         13         13       1172
# 7           2          2         88          1          2        151
# 8           0          3        199          1          4        209
# 9           0          1        109          1          1        311
# 10          0         14        885         11         16       1486
# 11          0          1         65          1          4        169
# 12          0          0         56          0          1         30
# 13          0          0         81          1          2        254
# 14          0          6        158          3          2        260
# 15          0          3        150          2          2        424
# 16          0          1        125          1          2        191
# 17          8         74      3,850         59         71      7,427
#
#    G18GOVOMAR G18GOVIBAR G18GOVOWRI G18LTGPZUC G18LTGRTUR G18LTGONGO  \
# 0           7          4          3        435        352          9
# 1           5         17          2        374        310          8
# 2           7         10          1        553        559         12
# 3           2          7          2        160        239          5
# 4           6         14          6        593        532         16
# 5           1          2          2        122        119          1
# 6          10         22         11        726        933         21
# 7           2          3          4        116        127          4
# 8           3          6          3        272        145          5
# 9           4          3          1        201        225          5
# 10         18         19          7       1250       1164         29
# 11          2          6          2        109        134          4
# 12          2          1          0         70         18          1
# 13          5          1          4        147        192          3
# 14          4          7          7        240        199          7
# 15          1          2          5        245        332          3
# 16          2          1          4        164        159          4
# 17         81        125         64      5,777      5,739        137
#
#    G18LTGOWRI G18TREDPEA G18TRERMOR G18TREOWRI G18SOSRPAI G18SOSDCON  \
# 0           0        465        311          1        294        475
# 1           0        389        287          2        261        399
# 2           1        681        418          0        404        690
# 3           0        200        188          1        201        182
# 4           0        722        390          0        365        730
# 5           0        141         96          1         90        141
# 6           0        883        758          1        726        861
# 7           0        130        114          0        111        120
# 8           0        306        109          0        105        305
# 9           0        258        168          0        181        237
# 10          1       1468        931          1        866       1484
# 11          0        128        115          0        105        123
# 12          0         73         15          0         16         63
# 13          0        179        162          1        147        184
# 14          0        273        161          0        164        257
# 15          0        271        297          0        277        289
# 16          0        182        138          0        128        179
# 17          2      6,749      4,658          8      4,441      6,719
#
#    G18SOSOHEB G18SOSOWRI G18AUDDHOF G18AUDOBRO G18AUDRKEN G18AUDOWRI  \
# 0          20          0        435         28        314          0
# 1          21          0        350         41        277          0
# 2          18          0        632         27        431          0
# 3          16          0        161         18        207          0
# 4          34          0        622         56        412          1
# 5           7          0        133          9         93          0
# 6          57          0        752         74        788          1
# 7          15          2        112         13        111          0
# 8           8          1        270         15        117          0
# 9           9          0        211         10        201          0
# 10         77          0       1281        128        952          1
# 11         10          0        106         15        110          0
# 12          7          0         60          7         16          0
# 13         11          0        139         27        167          0
# 14         15          0        231         32        167          0
# 15         10          0        252         19        287          0
# 16         17          0        164         18        135          0
# 17        352          3      5,911        537      4,785          3
#
#    G18ATGRWIL G18ATGOJAC G18ATGDDON G18ATGOWRI     County
# 0         297         20        473          0  Caledonia
# 1         279         21        384          1  Caledonia
# 2         412         22        669          1  Caledonia
# 3         184         14        197          0  Caledonia
# 4         363         36        728          0  Caledonia
# 5          90          5        145          0  Caledonia
# 6         754         36        866          1  Caledonia
# 7         112          9        124          0  Caledonia
# 8         106         11        300          0  Caledonia
# 9         169          9        246          0  Caledonia
# 10        911         68       1442          3  Caledonia
# 11        102          8        133          0  Caledonia
# 12         13          6         70          0  Caledonia
# 13        154         13        174          0  Caledonia
# 14        155         14        264          1  Caledonia
# 15        269         12        290          0  Caledonia
# 16        131         12        178          0  Caledonia
# 17      4,501        316      6,683          7  Caledonia

# %%
final_df = pd.concat(final_dfs, axis=0)
final_df["ID"] = final_df["ID"].astype('str').str.replace("\r", " ")
final_df["NAME"] = final_df["NAME"].astype('str').str.replace("\r", " ")

final_df["ID"] = final_df["ID"].astype('str').str.replace("\n", " ")
final_df["NAME"] = final_df["NAME"].astype('str').str.replace("\n", " ")

# %%
final_df.head()
# Out:
#                     ID         NAME G18USSISAN G18USSIPEA G18USSIBUS  \
# 0      Addison ADDISON      ADDISON        330          4          0
# 1     Addison BRIDPORT     BRIDPORT        307          5          3
# 2      Addison BRISTOL      BRISTOL       1172         13          4
# 3     Addison CORNWALL     CORNWALL        543          4          1
# 4  Addison FERRISBURGH  FERRISBURGH        913         11          3
#
#   G18USSIGIL G18USSIADE G18USSISVI G18USSRZUP G18USSOKAN G18USSIBES  \
# 0          4          4         21        266          2          5
# 1          2          6         16        230          0          6
# 2          7         14         27        445          7         18
# 3          0          5          6        135          1          1
# 4          7         15         14        442          2          9
#
#   G18USSOWRI G18HALRTYN G18HALIERI G18HALOPOT G18HALDWEL G18HALOWRI  \
# 0          0        253         23          6        353          0
# 1          0        200         30          4        331          0
# 2          0        438         66         21       1182          0
# 3          2        126         18          2        549          1
# 4          3        421         31         16        945          0
#
#   G18GOVILAR G18GOVDHAL G18GOVIERI G18GOVOPEY G18GOVRSCO G18GOVOMAR  \
# 0          5        154          7          5        465          1
# 1          2        139          3          7        429          1
# 2          9        694         12          9        949          5
# 3          3        336          0          4        346          6
# 4          4        496         10          4        888          7
#
#   G18GOVIBAR G18GOVOWRI G18LTGPZUC G18LTGRTUR G18LTGONGO G18LTGOWRI  \
# 0          4          3        245        386          5          0
# 1          2          1        247        327          3          0
# 2         29          8       1002        674         27          1
# 3          4          1        488        200          6          0
# 4          9          2        759        647          9          1
#
#   G18TREDPEA G18TRERMOR G18TREOWRI G18SOSRPAI G18SOSDCON G18SOSOHEB  \
# 0        306        318          0        282        324         16
# 1        291        270          0        233        313         14
# 2       1131        539          0        482       1137         60
# 3        515        152          0        144        523         16
# 4        901        492          0        466        905         27
#
#   G18SOSOWRI G18AUDDHOF G18AUDOBRO G18AUDRKEN G18AUDOWRI G18ATGRWIL  \
# 0          0        267         19        319          0        245
# 1          2        257         21        270          0        206
# 2          0       1017         63        548          2        416
# 3          0        479         14        160          1        123
# 4          0        819         44        494          0        402
#
#   G18ATGOJAC G18ATGDDON G18ATGOWRI   County
# 0          8        370          0  Addison
# 1         15        344          0  Addison
# 2         55       1201          0  Addison
# 3         16        543          0  Addison
# 4         22        977          1  Addison

# %% [markdown]
# #### So this is exceptionally weird, run this cell **TWICE** to save the correct .csv file

# %%
# Need to pass in these special arguments to take care of newline characters present in the dataframe
final_df.to_csv("raw-from-source/recreated/vest_from_pdf_dummy.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)

test = pd.read_csv("raw-from-source/recreated/vest_from_pdf.csv")


test = test.astype('str')
final_df = final_df.astype('str')

test.reset_index(inplace=True)
final_df.reset_index(inplace=True)
print(final_df.equals(test))
# so some corruptions are occuring as this file is being saved to .csv, let's see what is going on.
# Out:
# False

# %%
final_df.head()
# Out:
#    index                   ID         NAME G18USSISAN G18USSIPEA G18USSIBUS  \
# 0      0      Addison ADDISON      ADDISON        330          4          0
# 1      1     Addison BRIDPORT     BRIDPORT        307          5          3
# 2      2      Addison BRISTOL      BRISTOL       1172         13          4
# 3      3     Addison CORNWALL     CORNWALL        543          4          1
# 4      4  Addison FERRISBURGH  FERRISBURGH        913         11          3
#
#   G18USSIGIL G18USSIADE G18USSISVI G18USSRZUP G18USSOKAN G18USSIBES  \
# 0          4          4         21        266          2          5
# 1          2          6         16        230          0          6
# 2          7         14         27        445          7         18
# 3          0          5          6        135          1          1
# 4          7         15         14        442          2          9
#
#   G18USSOWRI G18HALRTYN G18HALIERI G18HALOPOT G18HALDWEL G18HALOWRI  \
# 0          0        253         23          6        353          0
# 1          0        200         30          4        331          0
# 2          0        438         66         21       1182          0
# 3          2        126         18          2        549          1
# 4          3        421         31         16        945          0
#
#   G18GOVILAR G18GOVDHAL G18GOVIERI G18GOVOPEY G18GOVRSCO G18GOVOMAR  \
# 0          5        154          7          5        465          1
# 1          2        139          3          7        429          1
# 2          9        694         12          9        949          5
# 3          3        336          0          4        346          6
# 4          4        496         10          4        888          7
#
#   G18GOVIBAR G18GOVOWRI G18LTGPZUC G18LTGRTUR G18LTGONGO G18LTGOWRI  \
# 0          4          3        245        386          5          0
# 1          2          1        247        327          3          0
# 2         29          8       1002        674         27          1
# 3          4          1        488        200          6          0
# 4          9          2        759        647          9          1
#
#   G18TREDPEA G18TRERMOR G18TREOWRI G18SOSRPAI G18SOSDCON G18SOSOHEB  \
# 0        306        318          0        282        324         16
# 1        291        270          0        233        313         14
# 2       1131        539          0        482       1137         60
# 3        515        152          0        144        523         16
# 4        901        492          0        466        905         27
#
#   G18SOSOWRI G18AUDDHOF G18AUDOBRO G18AUDRKEN G18AUDOWRI G18ATGRWIL  \
# 0          0        267         19        319          0        245
# 1          2        257         21        270          0        206
# 2          0       1017         63        548          2        416
# 3          0        479         14        160          1        123
# 4          0        819         44        494          0        402
#
#   G18ATGOJAC G18ATGDDON G18ATGOWRI
# 0          8        370          0
# 1         15        344          0
# 2         55       1201          0
# 3         16        543          0
# 4         22        977          1

# %%
test.head()
# Out:
#                     ID         NAME G18USSISAN G18USSIPEA G18USSIBUS  \
# 0      Addison ADDISON      ADDISON        330          4          0
# 1     Addison BRIDPORT     BRIDPORT        307          5          3
# 2      Addison BRISTOL      BRISTOL       1172         13          4
# 3     Addison CORNWALL     CORNWALL        543          4          1
# 4  Addison FERRISBURGH  FERRISBURGH        913         11          3
#
#   G18USSIGIL G18USSIADE G18USSISVI G18USSRZUP G18USSOKAN G18USSIBES  \
# 0          4          4         21        266          2          5
# 1          2          6         16        230          0          6
# 2          7         14         27        445          7         18
# 3          0          5          6        135          1          1
# 4          7         15         14        442          2          9
#
#   G18USSOWRI G18HALRTYN G18HALIERI G18HALOPOT G18HALDWEL G18HALOWRI  \
# 0          0        253         23          6        353          0
# 1          0        200         30          4        331          0
# 2          0        438         66         21       1182          0
# 3          2        126         18          2        549          1
# 4          3        421         31         16        945          0
#
#   G18GOVILAR G18GOVDHAL G18GOVIERI G18GOVOPEY G18GOVRSCO G18GOVOMAR  \
# 0          5        154          7          5        465          1
# 1          2        139          3          7        429          1
# 2          9        694         12          9        949          5
# 3          3        336          0          4        346          6
# 4          4        496         10          4        888          7
#
#   G18GOVIBAR G18GOVOWRI G18LTGPZUC G18LTGRTUR G18LTGONGO G18LTGOWRI  \
# 0          4          3        245        386          5          0
# 1          2          1        247        327          3          0
# 2         29          8       1002        674         27          1
# 3          4          1        488        200          6          0
# 4          9          2        759        647          9          1
#
#   G18TREDPEA G18TRERMOR G18TREOWRI G18SOSRPAI G18SOSDCON G18SOSOHEB  \
# 0        306        318          0        282        324         16
# 1        291        270          0        233        313         14
# 2       1131        539          0        482       1137         60
# 3        515        152          0        144        523         16
# 4        901        492          0        466        905         27
#
#   G18SOSOWRI G18AUDDHOF G18AUDOBRO G18AUDRKEN G18AUDOWRI G18ATGRWIL  \
# 0          0        267         19        319          0        245
# 1          2        257         21        270          0        206
# 2          0       1017         63        548          2        416
# 3          0        479         14        160          1        123
# 4          0        819         44        494          0        402
#
#   G18ATGOJAC G18ATGDDON G18ATGOWRI
# 0          8        370          0
# 1         15        344          0
# 2         55       1201          0
# 3         16        543          0
# 4         22        977          1

# %%
for col in final_df:
    f = final_df[col].astype('str')
    t = test[col].astype('str')
    
    diff = f.ne(t).to_list()
    print(type(diff))
    print(f[diff])
    print(t[diff])
    
    npf = final_df[col].astype('str').to_numpy()
    npt = test[col].astype('str').to_numpy()
    
    if not np.array_equal(npf, npt):
        print("Np not equal")
        
        print(np.where(npt != npf))
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-125-cd849120446e> in <module>
#       5     diff = f.ne(t).to_list()
#       6     print(type(diff))
# ----> 7     print(f[diff])
#       8     print(t[diff])
#       9
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     871
#     872         if com.is_bool_indexer(key):
# --> 873             key = check_bool_indexer(self.index, key)
#     874             key = np.asarray(key, dtype=bool)
#     875             return self._get_values(key)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2280         # key may contain nan elements, check_array_indexer needs bool array
#    2281         result = pd_array(result, dtype=bool)
# -> 2282     return check_array_indexer(index, result)
#    2283
#    2284
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexers.py in check_array_indexer(array, indexer)
#     483         # GH26658
#     484         if len(indexer) != len(array):
# --> 485             raise IndexError(
#     486                 f"Boolean index has wrong length: "
#     487                 f"{len(indexer)} instead of {len(array)}"
#
# IndexError: Boolean index has wrong length: 491 instead of 260
